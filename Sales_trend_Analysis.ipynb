# %% [markdown]
# <a href="https://colab.research.google.com/github/vidushi1920/Data-Analysis-of-an-E-COMMERCE-website/blob/main/Sales_trend_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Vidushi Goyal
# Thapar Institute of Engineering and Technology, Patiala
# 9888814762
# Case - Study -- E-Commerce

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/od.csv')
df = pd.DataFrame(data)
df.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category
# 0  B-25601    1275   -1148         7    Furniture         Bookcases
# 1  B-25601      66     -12         5     Clothing             Stole
# 2  B-25601       8      -2         3     Clothing       Hankerchief
# 3  B-25601      80     -56         4  Electronics  Electronic Games
# 4  B-25602     168    -111         2  Electronics            Phones

# %%
cop = df
cop.replace({'Electronics':0,'Clothing':1,'Furniture':2},inplace = True)

# %%
c = cop.corr()
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(c,annot = True)
plt.show()

# %%
orders = pd.read_csv('/content/orders - orders.csv')
orders = pd.DataFrame(orders)
orders.head()
# Out:
#   Order ID  Order Date CustomerName           State       City     Date
# 0  B-25601  04-01-2018       Bharat         Gujarat  Ahmedabad  01-2018
# 1  B-25602  04-01-2018        Pearl     Maharashtra       Pune  01-2018
# 2  B-25603  04-03-2018        Jahan  Madhya Pradesh     Bhopal  03-2018
# 3  B-25604  04-03-2018       Divsha       Rajasthan     Jaipur  03-2018
# 4  B-25605  04-05-2018      Kasheen     West Bengal    Kolkata  05-2018

# %%
df = pd.merge(df,orders,on = 'Order ID')

# %%
df.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25601    1275   -1148         7    Furniture         Bookcases
# 1  B-25601      66     -12         5     Clothing             Stole
# 2  B-25601       8      -2         3     Clothing       Hankerchief
# 3  B-25601      80     -56         4  Electronics  Electronic Games
# 4  B-25602     168    -111         2  Electronics            Phones
#
#    Order Date CustomerName        State       City     Date
# 0  04-01-2018       Bharat      Gujarat  Ahmedabad  01-2018
# 1  04-01-2018       Bharat      Gujarat  Ahmedabad  01-2018
# 2  04-01-2018       Bharat      Gujarat  Ahmedabad  01-2018
# 3  04-01-2018       Bharat      Gujarat  Ahmedabad  01-2018
# 4  04-01-2018        Pearl  Maharashtra       Pune  01-2018

# %%
dfc = df
g = df.groupby(['Sub-Category']).sum()
#h = g.get_group('Electronic Games')
#e = h.groupby(['Date']).sum()
g.sort_values(by=['Profit'])
#e.to_csv('/content/eg2.csv')
# Out:
#                   Amount  Profit  Quantity
# Sub-Category
# Tables             22614   -4011        61
# Electronic Games   39168   -1236       297
# Kurti               3361     181       164
# Skirt               1946     235       248
# Leggings            2106     260       186
# Saree              53511     352       782
# Chairs             34222     577       277
# Furnishings        13484     844       310
# Shirt               7555    1131       271
# T-shirt             7382    1500       305
# Hankerchief        14608    2098       754
# Phones             46119    2207       304
# Stole              18546    2559       671
# Trousers           30039    2847       135
# Accessories        21728    3559       262
# Bookcases          56861    4888       297
# Printers           58252    5964       291

# %%
df['State'].unique()
# Out:
# array(['Gujarat', 'Maharashtra', 'Madhya Pradesh', 'Rajasthan',
#        'West Bengal', 'Karnataka', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Uttar Pradesh', 'Bihar', 'Kerala', 'Punjab', 'Haryana',
#        'Himachal Pradesh', 'Sikkim', 'Goa', 'Nagaland', 'Andhra Pradesh',
#        'Delhi'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
co_matrix = df.corr()
sns.heatmap(co_matrix,annot = True)
plt.show()

# %%
# Profit Over a Period
dfc = df
g = dfc.groupby(['Date']).sum()
#g.to_csv('/content/Profit_by_date.csv')
g.sort_values(by=['Profit'],ascending = False)
# Out:
#          Amount  Profit  Quantity
# Date
# 01-2019   50448    8655       640
# 03-2019   39700    6633       485
# 10-2018   32758    5979       414
# 11-2018   38858    4955       433
# 02-2019   15894    2291       253
# 10-2019   14147    1892       149
# 09-2019    5583    1597        70
# 12-2018   23892    1535       209
# 04-2019   11079    1295       106
# 07-2019    5116     975        67
# 05-2019    4390     943        63
# 06-2019    3392     700        52
# 02-2018    6566     685        58
# 03-2018    7434     669       144
# 08-2019    6557     594        83
# 11-2019    2235     122        35
# 12-2019     259      57         5
# 05-2018   20422    -891       306
# 04-2018   26170   -1043       337
# 08-2018   45269   -1059       601
# 07-2018   15682   -2065       239
# 01-2018   18035   -3296       203
# 09-2018   20210   -3509       310
# 06-2018   17406   -3759       353

# %%
g = dfc.groupby(['Date'])
g.get_group('01-2019')
# Out:
#      Order ID  Amount  Profit  Quantity     Category Sub-Category  Order Date  \
# 963   B-25928      25      10         1    Furniture  Furnishings  01-01-2019
# 964   B-25928     122      15         3  Electronics  Accessories  01-01-2019
# 1006  B-25947     290      35         6     Clothing  Hankerchief  13-01-2019
# 1007  B-25947     207      33         2  Electronics  Accessories  13-01-2019
# 1008  B-25948     152      23         3    Furniture  Furnishings  13-01-2019
# ...       ...     ...     ...       ...          ...          ...         ...
# 1295  B-26043     185      48         4     Clothing        Stole  03-01-2019
# 1296  B-26043      62      28         5     Clothing  Hankerchief  03-01-2019
# 1297  B-26043      79       5         6     Clothing  Hankerchief  03-01-2019
# 1298  B-26043      30      12         3     Clothing        Skirt  03-01-2019
# 1299  B-26043     122      50         7     Clothing        Stole  03-01-2019
#
# ...

# %%
# Profit by State
dfc = df
g = dfc.groupby(['State'])
#h = g.sort_values(by=['Profit'],ascending=False)

# %%
#to check for lowest profits
g.get_group('Tamil Nadu')
# Out:
#      Order ID  Amount  Profit  Quantity     Category Sub-Category  Order Date  \
# 22    B-25608    1364   -1864         5    Furniture       Tables  04-08-2018
# 23    B-25608     476       0         3    Furniture       Chairs  04-08-2018
# 24    B-25608     257      23         5     Clothing  Hankerchief  04-08-2018
# 25    B-25608     856     385         6  Electronics     Printers  04-08-2018
# 287   B-25698      87     -83         5     Clothing        Kurti  23-06-2018
# 288   B-25698      27      -6         4     Clothing  Hankerchief  23-06-2018
# 289   B-25698     207    -153         3     Clothing        Saree  23-06-2018
# 290   B-25698     516    -392         8    Furniture       Chairs  23-06-2018
# 291   B-25698       7      -2         1     Clothing  Hankerchief  23-06-2018
# 292   B-25698      65     -16         2  Electronics       Phones  23-06-2018
# 340   B-25716      58       0         4     Clothing        Saree  07-11-2018
# ...

# %%
g = dfc.groupby(['State']).mean()
g.sort_values(by=['Profit'],ascending=False)
# Out:
#                        Amount     Profit  Quantity
# State
# Haryana            340.884615  50.961538  4.269231
# Uttar Pradesh      328.808824  47.602941  4.235294
# Kerala             299.088889  41.577778  3.488889
# Delhi              304.472973  40.364865  3.743243
# West Bengal        223.587302  39.682540  3.428571
# Himachal Pradesh   298.827586  22.620690  3.896552
# Maharashtra        328.786207  21.296552  3.641379
# Rajasthan          285.797297  16.986486  3.810811
# Sikkim             219.833333  16.708333  3.875000
# Madhya Pradesh     309.235294  16.326471  4.000000
# Karnataka          278.851852  11.944444  3.333333
# Goa                155.930233   8.604651  3.372093
# Gujarat            242.045977   5.344828  3.770115
# Nagaland           264.511111   3.288889  3.844444
# Jammu and Kashmir  221.000000   0.163265  3.612245
# Bihar              208.758065  -5.177419  3.322581
# Punjab             279.766667 -10.150000  3.600000
# ...

# %%
g = dfc.groupby(['Category']).mean()
g.sort_values(by=['Profit'],ascending=False)
# Out:
#                  Amount     Profit  Quantity     Month
# Category
# Electronics  536.581169  34.071429  3.746753  5.896104
# Clothing     146.526870  11.762908  3.704953  6.093783
# Furniture    523.378601   9.456790  3.888889  6.078189

# %%
g = dfc.groupby(['Sub-Category']).sum()
g.sort_values(by=['Profit'],ascending=False)
# Out:
#                   Amount  Profit  Quantity
# Sub-Category
# Printers           58252    5964       291
# Bookcases          56861    4888       297
# Accessories        21728    3559       262
# Trousers           30039    2847       135
# Stole              18546    2559       671
# Phones             46119    2207       304
# Hankerchief        14608    2098       754
# T-shirt             7382    1500       305
# Shirt               7555    1131       271
# Furnishings        13484     844       310
# Chairs             34222     577       277
# Saree              53511     352       782
# Leggings            2106     260       186
# Skirt               1946     235       248
# Kurti               3361     181       164
# Electronic Games   39168   -1236       297
# Tables             22614   -4011        61

# %%
g = dfc.groupby(['Order ID']).sum()
g.sort_values(by=['Quantity'],ascending=False)
# Out:
#           Amount  Profit  Quantity
# Order ID
# B-26055     8502     683        57
# B-26051     4719     906        49
# B-25753     1500    -235        47
# B-25757     3912      55        47
# B-25955     6339     669        46
# ...          ...     ...       ...
# B-25720       30     -35         1
# B-25982       13       3         1
# B-26015      128      55         1
# B-26017       78       7         1
# B-25911       40      15         1
#
# [500 rows x 3 columns]

# %%
# the top names in the list are customers whose purchases are resulting in loss for us
g.sort_values(by=['Profit'],ascending=True)
# Out:
#           Amount  Profit  Quantity
# Order ID
# B-25798     3803   -1836        26
# B-25608     2953   -1456        19
# B-26022     1824   -1303         8
# B-25601     1429   -1218        19
# B-25779     1361    -980         3
# ...          ...     ...       ...
# B-25761     3339     984        28
# B-26093     4502    1020        28
# B-25656     3895    1021        43
# B-25855     4613    1432        32
# B-25973     5228    1970        40
#
# [500 rows x 3 columns]

# %%
t.to_csv('/content/profit_by_order-id.csv')

# %%
# The top names in the list are loyal customers
g = dfc.groupby(['CustomerName']).mean()
g.sort_values(by=['Profit'],ascending=False)
# Out:
#               Amount  Profit  Quantity  Month
# CustomerName
# Arpita        1301.0   573.0       5.0    9.0
# Pranjali      1250.0   486.0       7.0   10.0
# Seema         1045.6   394.0       8.0    1.0
# Yohann        1314.0   342.0       3.0    4.0
# Tanushree      637.0   261.0       2.0   10.0
# ...              ...     ...       ...    ...
# Swetha         352.0  -345.0       5.0   11.0
# Madhulika     1549.0  -439.0       4.0    7.0
# Shreyoshe     1582.0  -443.0       6.0    1.0
# Tanvi          934.0  -916.0       7.0    5.0
# Savi          1361.0  -980.0       3.0   12.0
#
# [332 rows x 4 columns]

# %%
# the top names in the list are customers whose purchases are resulting in loss for us
g = dfc.groupby(['CustomerName']).mean()
g.sort_values(by=['Profit'],ascending=True)
# Out:
#               Amount  Profit  Quantity  Month
# CustomerName
# Savi          1361.0  -980.0       3.0   12.0
# Tanvi          934.0  -916.0       7.0    5.0
# Shreyoshe     1582.0  -443.0       6.0    1.0
# Madhulika     1549.0  -439.0       4.0    7.0
# Swetha         352.0  -345.0       5.0   11.0
# ...              ...     ...       ...    ...
# Tanushree      637.0   261.0       2.0   10.0
# Yohann        1314.0   342.0       3.0    4.0
# Seema         1045.6   394.0       8.0    1.0
# Pranjali      1250.0   486.0       7.0   10.0
# Arpita        1301.0   573.0       5.0    9.0
#
# [332 rows x 4 columns]

# %%
g1 = dfc.groupby(['Category'])

# %%
g1.get_group('Furniture').sort_values(by=['Profit'])
# Out:
#     Order ID  Amount  Profit  Quantity   Category Sub-Category Order Date  \
# 589  B-25798    2830   -1981        13  Furniture    Bookcases 2018-01-10
# 22   B-25608    1364   -1864         5  Furniture       Tables 2018-08-04
# 0    B-25601    1275   -1148         7  Furniture    Bookcases 2018-01-04
# 529  B-25779    1361    -980         3  Furniture       Tables 2018-12-09
# 585  B-25797    1630    -802         5  Furniture       Tables 2018-09-30
# ..       ...     ...     ...       ...        ...          ...        ...
# 982  B-25935    1657     460         4  Furniture       Chairs 2019-04-01
# 965  B-25929    1308     536         3  Furniture    Bookcases 2019-02-01
# 789  B-25862    2061     701         5  Furniture    Bookcases 2018-11-15
# 743  B-25853    2093     721         5  Furniture       Chairs 2018-08-11
# 483  B-25761    2188    1050         5  Furniture    Bookcases 2018-08-25
#
#     CustomerName           State                City     Date  Month
# ...

# %% [markdown]
# Calculating the mean profit of every category:

# %%
clothing = g1.get_group('Clothing')
c = clothing['Profit']
c.mean()
# Out:
# 11.76290832455216

# %%
electronics = g1.get_group('Electronics')
e = electronics['Profit']
e.mean()
# Out:
# 34.07142857142857

# %%
furniture = g1.get_group('Furniture')
f = furniture['Profit']
f.mean()
# Out:
# 9.45679012345679

# %% [markdown]
# Analysing worst performing category:

# %%
furniture = g1.get_group('Furniture')
f = furniture['Profit']
f1 = furniture.groupby(['Sub-Category'])
furniture.sort_values(by=['Profit'],ascending=False)
# Out:
#     Order ID  Amount  Profit  Quantity   Category Sub-Category Order Date  \
# 483  B-25761    2188    1050         5  Furniture    Bookcases 2018-08-25
# 743  B-25853    2093     721         5  Furniture       Chairs 2018-08-11
# 789  B-25862    2061     701         5  Furniture    Bookcases 2018-11-15
# 965  B-25929    1308     536         3  Furniture    Bookcases 2019-02-01
# 982  B-25935    1657     460         4  Furniture       Chairs 2019-04-01
# ..       ...     ...     ...       ...        ...          ...        ...
# 585  B-25797    1630    -802         5  Furniture       Tables 2018-09-30
# 529  B-25779    1361    -980         3  Furniture       Tables 2018-12-09
# 0    B-25601    1275   -1148         7  Furniture    Bookcases 2018-01-04
# 22   B-25608    1364   -1864         5  Furniture       Tables 2018-08-04
# 589  B-25798    2830   -1981        13  Furniture    Bookcases 2018-01-10
#
#     CustomerName           State                City     Date  Month
# ...

# %%
# Furniture is the worst performing Category
# Printers have the highest total and average profit

# %%
furniture.drop('Category',inplace=True,axis = 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
furniture
# Out:
#      Order ID  Amount  Profit  Quantity Sub-Category Order Date CustomerName  \
# 0     B-25601    1275   -1148         7    Bookcases 2018-01-04       Bharat
# 10    B-25603      24     -30         1       Chairs 2018-03-04        Jahan
# 22    B-25608    1364   -1864         5       Tables 2018-08-04      Aarushi
# 23    B-25608     476       0         3       Chairs 2018-08-04      Aarushi
# 33    B-25610      30      -5         2  Furnishings 2018-09-04       Yogesh
# ...       ...     ...     ...       ...          ...        ...          ...
# 1431  B-26081     359    -338         5    Bookcases 2019-03-22      Aarushi
# 1467  B-26093     852      51         5    Bookcases 2019-03-27       Sarita
# 1484  B-26097     185     -26         6       Chairs 2019-03-28         Vini
# 1488  B-26098     497     179         3       Chairs 2019-03-29        Pinky
# 1497  B-26100     828     230         2       Chairs 2019-03-31       Hitika
#
# ...

# %%
f1 = furniture.groupby(['Sub-Category']).mean()
f1.sort_values(by=['Profit'],ascending = False)
# Out:
#                    Amount      Profit  Quantity     Month
# Sub-Category
# Bookcases      719.759494   61.873418  3.759494  5.835443
# Furnishings    184.712329   11.561644  4.246575  5.876712
# Chairs         462.459459    7.797297  3.743243  6.229730
# Tables        1330.235294 -235.941176  3.588235  7.411765

# %%
# Tables are the worst performing entity

# %%
# Analysing profit trends in different months

# %%
g3 = dfc.groupby(['Month'])

# %%
January = g3.get_group(1)
January.sort_values(by=['Profit'],ascending = False)
January.drop('Month',inplace=True,axis = 1)
j = January.groupby(['Sub-Category']).sum()
j.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Printers           12927    2739        50
# Phones              7703    1409        57
# Stole               3724     598       128
# Accessories         3291     547        33
# Electronic Games    6340     449        49
# Chairs              1747     420        17
# Hankerchief         2344     308       120
# Saree               4179     287        74
# Shirt               1016     192        39
# Furnishings         1829     187        47
# T-shirt             1172     177        43
# Skirt                369     104        38
# Kurti                363      65        14
# ...

# %%
feb = g3.get_group(2)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Bookcases           3242    1308        19
# Printers            3017     569        14
# Accessories         1874     488        20
# Electronic Games    1578     276        12
# Saree               2054     219        33
# Stole                876     219        36
# T-shirt              731     218        21
# Shirt                564     211        21
# Furnishings         1174     203        28
# Hankerchief          951     185        41
# Trousers             833      93         3
# Skirt                 68      25         7
# Leggings              67       9         4
# ...

# %%
feb = g3.get_group(3)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Printers           10277    2163        42
# Trousers            5727    1124        20
# Saree               4873     578        79
# Stole               2625     507        89
# Accessories         1934     495        24
# Furnishings         1717     487        35
# Phones              2497     438        21
# Chairs              1757     327        16
# T-shirt             1228     318        51
# Hankerchief         1459     310        78
# Tables              4363     305         5
# Leggings             589     164        38
# Kurti                529     161        25
# ...

# %%
feb = g3.get_group(4)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Bookcases           7339     758        31
# Trousers            3751     693        18
# Shirt               1236     249        34
# Tables              1461     202         5
# Accessories          919     157        11
# Stole               1347     124        45
# Chairs              4028      84        24
# Skirt                185      33        17
# Leggings              78      28         5
# Printers            1381       9         7
# T-shirt               64      -9         5
# Kurti                217     -54        10
# Hankerchief         1238     -63        70
# ...

# %%
feb = g3.get_group(5)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Printers            2402     741        15
# Bookcases           2356     337        10
# T-shirt              693     153        35
# Trousers            1591     139         9
# Hankerchief          617     123        27
# Stole               1086      83        31
# Kurti                329      73         8
# Shirt                428      62        17
# Leggings              62      17         6
# Skirt                150       0        21
# Phones              2864     -15        27
# Tables               610     -66         2
# Furnishings         1589    -128        32
# ...

# %%
#  trend can be seen between the clothing items and seasons --- warmer clothes are being purchased in winters and cotton/coller clothes in summers

# %%
feb = g3.get_group(6)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# T-shirt              958     139        35
# Printers            4112      78        25
# Trousers             384      72         6
# Bookcases            336      71         3
# Leggings             130       2        13
# Skirt                101      -5        12
# Phones              1335     -12        23
# Furnishings          203     -17        10
# Accessories          427     -33         9
# Kurti                288     -37        17
# Stole                679     -97        30
# Shirt                713    -221        34
# Hankerchief          930    -254        63
# ...

# %%
feb = g3.get_group(7)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Printers            2712     555        12
# Tables              2641     242         9
# Shirt                608     188        14
# Accessories          677     118         6
# T-shirt              253      80        11
# Trousers             830      58         6
# Stole               1025      40        49
# Kurti                105      33         5
# Bookcases           2203      30        24
# Hankerchief          314      25        39
# Electronic Games    1099      24        17
# Skirt                136     -19        24
# Leggings             109     -42        12
# ...

# %%
feb = g3.get_group(8)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Chairs              5652     840        33
# Bookcases           6654     649        33
# Trousers            5201     444        16
# Hankerchief         1775     361        77
# Furnishings         2670     260        47
# Accessories         2217     188        29
# Stole               1856     168        75
# T-shirt              756     151        38
# Shirt                 77      21         5
# Skirt                268      -8        49
# Leggings             224     -34        26
# Kurti                405     -68        27
# Electronic Games    4472    -304        42
# ...

# %%
feb = g3.get_group(9)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Accessories         4418    1179        38
# Bookcases           4136     556        24
# Hankerchief          867      77        46
# T-shirt              215      43         9
# Electronic Games     527      26         5
# Leggings             105      16        12
# Phones               623       0         7
# Skirt                 85      -5        12
# Shirt                401      -9        13
# Kurti                165     -45        13
# Stole                746    -140        38
# Furnishings          369    -228        20
# Trousers            1326    -372         7
# ...

# %%
feb = g3.get_group(10)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Phones              6271    1736        38
# Saree               7069    1656        79
# Printers            6430    1054        35
# Bookcases           4875     792        28
# Hankerchief         2389     652       112
# Electronic Games    3348     459        15
# Stole               1851     456        53
# Accessories         2739     393        45
# Chairs              6998     300        27
# Trousers            1924     172         6
# Furnishings         1406     100        26
# Shirt                717      79        36
# T-shirt              415      51        22
# ...

# %%
feb = g3.get_group(11)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Bookcases           5265    1799        20
# Trousers            3760     767        12
# Saree               7346     490        82
# Phones              1839     440         7
# Stole               1801     349        65
# Electronic Games    7031     346        35
# Hankerchief         1465     327        76
# Chairs              4149     295        25
# Accessories          464     182         9
# Shirt                651     157        17
# Tables              2947     150         8
# T-shirt              377     120        18
# Kurti                475      79        18
# ...

# %%
feb = g3.get_group(12)
feb.sort_values(by=['Profit'],ascending = False)
feb.drop('Month',inplace=True,axis = 1)
f = feb.groupby(['Sub-Category']).sum()
f.sort_values(by=['Profit'],ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                   Amount  Profit  Quantity
# Sub-Category
# Phones              7165    1570        26
# Electronic Games    3287     274        21
# Saree               2470     265        20
# Stole                930     252        32
# Printers            1120     232         5
# Bookcases            831     146         4
# Chairs              2150     123        12
# Furnishings          244     122         5
# T-shirt              520      59        17
# Hankerchief          259      47         5
# Shirt                389      43        14
# Kurti                219      40         6
# Skirt                 92      28        11
# ...

# %%
# electronic games sales can be seen heavily associated with seasons -- stay at home months see a rise in the sales

# %%
df['State'].unique()
# Out:
# array(['Gujarat', 'Maharashtra', 'Madhya Pradesh', 'Rajasthan',
#        'West Bengal', 'Karnataka', 'Jammu and Kashmir', 'Tamil Nadu',
#        'Uttar Pradesh', 'Bihar', 'Kerala ', 'Punjab', 'Haryana',
#        'Himachal Pradesh', 'Sikkim', 'Goa', 'Nagaland', 'Andhra Pradesh',
#        'Delhi'], dtype=object)

# %%
g4 = dfc.groupby(['State'])
w = g4.get_group('Gujarat')
w.drop('State',inplace = True,axis = 1)
w = w.groupby('City')
er = w.get_group('Ahmedabad')
er.sort_values(by=['Sub-Category'],ascending=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      Order ID  Amount  Profit  Quantity     Category Sub-Category Order Date  \
# 533   B-25781     767    -353         5     Clothing     Trousers 2018-09-14
# 1464  B-26092      97      14         2     Clothing      T-shirt 2019-03-27
# 1267  B-26029      21      10         1     Clothing      T-shirt 2019-02-20
# 532   B-25781      30     -25         2     Clothing      T-shirt 2018-09-14
# 216   B-25673      37      -5         3     Clothing      T-shirt 2018-05-28
# ...       ...     ...     ...       ...          ...          ...        ...
# 0     B-25601    1275   -1148         7    Furniture    Bookcases 2018-01-04
# ...
